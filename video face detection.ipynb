# %%
import cv2
cap=cv2.VideoCapture(0)
from mtcnn import MTCNN

detector =MTCNN()
while True:
    ret,frame=cap.read()
    
    
    for i in output:
        x,y,width,height=i['box']
        lefteyeX,lefteyeY=i['keypoints']['left_eye']
        righteyeX,righteyeY=i['keypoints']['right_eye']
        noseX,noseY=i['keypoints']['nose']
        mouthleftX,mouthleftY=i['keypoints']['mouth_left']
        mouthrightX,mouthrightY=i['keypoints']['mouth_right']

        cv2.circle(frame,center=(lefteyeX,lefteyeY),thickness=1,radius=5,color=(0,255,255))
        cv2.circle(frame,center=(righteyeX,righteyeY),thickness=1,radius=5,color=(0,255,255))
        cv2.circle(frame,center=(noseX,noseY),thickness=1,radius=5,color=(0,255,255))
        cv2.circle(frame,center=(mouthleftX,mouthleftY),thickness=1,radius=5,color=(0,255,255))
        cv2.circle(frame,center=(mouthrightX,mouthrightY),thickness=1,radius=5,color=(0,255,255))
        cv2.rectangle(frame,pt1=(x,y),pt2=(x+width,y+height),color=(255,255,0),thickness=2)
        output=detector.detect_faces(frame)
        cv2.imshow('window',frame)
        
        if cv2.waitKey(1)& 0xFF==ord('x'):
            break
    
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 31ms/step
